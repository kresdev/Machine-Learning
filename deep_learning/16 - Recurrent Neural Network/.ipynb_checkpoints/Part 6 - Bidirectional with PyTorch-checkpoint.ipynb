# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
df = pd.read_csv("data/daily_min_temp.csv", index_col="Date", parse_dates=["Date"])
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.Temp.plot(figsize=(15, 5), color='b')

# %% [markdown]
# ## Dataset Splitting

# %%
# X = df.Temp
# y = df.Temp

ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle=False)
ts_train.shape, ts_test.shape
# Out:
# ((2920, 1), (730, 1))

# %% [markdown]
# ## Dataset & Dataloader

# %%
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader

# %%
seq_len = 14
bs = 32

train_set = TimeSeriesDataset(ts_train, "Temp", seq_len)
trainloader = DataLoader(train_set, batch_size=bs)

test_set = TimeSeriesDataset(ts_test, "Temp", seq_len)
testloader = DataLoader(test_set, batch_size=bs)
# Out:
# (N, S, F): (208, 14, 1)
# Note: last 7 data excluded
#
# (N, S, F): (52, 14, 1)
# Note: last 1 data excluded

# %% [markdown]
# ## Arsitektur & Config

# %%
class GRU(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, num_layers, dropout):
        super().__init__()
        
        self.rnn = nn.GRU(input_size, hidden_size, num_layers, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden

# %%
config = set_config({
    "input_size": train_set.n_feature,
    "seq_len": train_set.n_seq,
    "output_size": 1,
    "hidden_size": 64,
    "num_layers": 2,
    "dropout": 0
})

# %% [markdown]
# ## Training Preparation -> MCOC

# %%
model = GRU(config.input_size, config.output_size, config.hidden_size, config.num_layers, config.dropout).to(device)
criterion = nn.MSELoss(reduction="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, outdir="model/gru")

# %% [markdown]
# ## Training

# %%
from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     1
# Train_cost  = 134.1216 | Test_cost  = 128.8863 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     2
# Train_cost  = 113.1964 | Test_cost  = 108.2968 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     3
# Train_cost  = 93.9311 | Test_cost  = 89.7153 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     4
# Train_cost  = 77.5651 | Test_cost  = 75.6063 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     5
# Train_cost  = 65.7349 | Test_cost  = 65.5653 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     6
# Train_cost  = 57.1498 | Test_cost  = 57.7515 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     7
# Train_cost  = 50.3057 | Test_cost  = 51.2416 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     8
# Train_cost  = 44.5749 | Test_cost  = 45.6992 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     9
# Train_cost  = 39.7090 | Test_cost  = 40.9550 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    10
# Train_cost  = 35.5710 | Test_cost  = 36.9003 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    11
# Train_cost  = 32.0643 | Test_cost  = 33.4488 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    12
# Train_cost  = 29.1088 | Test_cost  = 30.5260 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    13
# Train_cost  = 26.6342 | Test_cost  = 28.0648 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    14
# Train_cost  = 24.5766 | Test_cost  = 26.0041 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    15
# Train_cost  = 22.8780 | Test_cost  = 24.2888 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    16
# Train_cost  = 21.4864 | Test_cost  = 22.8695 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    17
# Train_cost  = 20.3555 | Test_cost  = 21.7021 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    18
# Train_cost  = 19.4438 | Test_cost  = 20.7474 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    19
# Train_cost  = 18.7149 | Test_cost  = 19.9709 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    20
# Train_cost  = 18.1368 | Test_cost  = 19.3425 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    21
# Train_cost  = 17.6820 | Test_cost  = 18.8363 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    22
# Train_cost  = 17.3270 | Test_cost  = 18.4301 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    23
# Train_cost  = 17.0520 | Test_cost  = 18.1052 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    24
# Train_cost  = 16.8405 | Test_cost  = 17.8461 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    25
# Train_cost  = 16.6789 | Test_cost  = 17.6398 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    26
# Train_cost  = 16.5561 | Test_cost  = 17.4756 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    27
# Train_cost  = 16.4632 | Test_cost  = 17.3451 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    28
# Train_cost  = 16.3932 | Test_cost  = 17.2412 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    29
# Train_cost  = 16.3405 | Test_cost  = 17.1583 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    30
# Train_cost  = 16.3008 | Test_cost  = 17.0922 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    31
# Train_cost  = 16.2708 | Test_cost  = 17.0391 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    32
# Train_cost  = 16.2480 | Test_cost  = 16.9965 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    33
# Train_cost  = 16.2304 | Test_cost  = 16.9620 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    34
# Train_cost  = 16.2165 | Test_cost  = 16.9340 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    35
# Train_cost  = 16.2054 | Test_cost  = 16.9111 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    36
# Train_cost  = 16.1962 | Test_cost  = 16.8922 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    37
# Train_cost  = 16.1882 | Test_cost  = 16.8765 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    38
# Train_cost  = 16.1810 | Test_cost  = 16.8631 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    39
# Train_cost  = 16.1742 | Test_cost  = 16.8514 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    40
# Train_cost  = 16.1673 | Test_cost  = 16.8409 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    41
# Train_cost  = 16.1601 | Test_cost  = 16.8310 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    42
# Train_cost  = 16.1519 | Test_cost  = 16.8209 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    43
# Train_cost  = 16.1419 | Test_cost  = 16.8094 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    44
# Train_cost  = 16.1288 | Test_cost  = 16.7941 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    45
# Train_cost  = 16.1091 | Test_cost  = 16.7709 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    46
# Train_cost  = 16.0777 | Test_cost  = 16.7346 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    47
# Train_cost  = 16.0228 | Test_cost  = 16.6659 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    48
# Train_cost  = 15.9315 | Test_cost  = 16.5838 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    49
# Train_cost  = 15.7971 | Test_cost  = 16.3816 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    50
# Train_cost  = 15.5302 | Test_cost  = 16.1419 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    51
# Train_cost  = 15.2247 | Test_cost  = 15.5946 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    52
# Train_cost  = 14.6762 | Test_cost  = 14.9939 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    53
# Train_cost  = 13.9414 | Test_cost  = 13.8362 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    54
# Train_cost  = 12.7438 | Test_cost  = 12.5929 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    55
# Train_cost  = 11.8300 | Test_cost  = 12.0243 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    56
# Train_cost  = 11.3215 | Test_cost  = 11.3704 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    57
# Train_cost  = 10.7683 | Test_cost  = 10.7994 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    58
# Train_cost  = 10.3455 | Test_cost  = 10.2862 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    59
# Train_cost  = 9.9496 | Test_cost  = 9.8289 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    60
# Train_cost  = 9.6106 | Test_cost  = 9.4283 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    61
# Train_cost  = 9.3057 | Test_cost  = 9.0874 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    62
# Train_cost  = 9.0473 | Test_cost  = 8.7825 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    63
# Train_cost  = 8.8216 | Test_cost  = 8.4978 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    64
# Train_cost  = 8.6153 | Test_cost  = 8.2545 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    65
# Train_cost  = 8.4358 | Test_cost  = 8.0402 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    66
# Train_cost  = 8.2778 | Test_cost  = 7.8401 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    67
# Train_cost  = 8.1320 | Test_cost  = 7.6591 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    68
# Train_cost  = 7.9988 | Test_cost  = 7.4975 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    69
# Train_cost  = 7.8783 | Test_cost  = 7.3501 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    70
# Train_cost  = 7.7683 | Test_cost  = 7.2158 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    71
# Train_cost  = 7.6677 | Test_cost  = 7.0943 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    72
# Train_cost  = 7.5758 | Test_cost  = 6.9836 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    73
# Train_cost  = 7.4915 | Test_cost  = 6.8825 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    74
# Train_cost  = 7.4143 | Test_cost  = 6.7903 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    75
# Train_cost  = 7.3435 | Test_cost  = 6.7058 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    76
# Train_cost  = 7.2787 | Test_cost  = 6.6280 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    77
# Train_cost  = 7.2190 | Test_cost  = 6.5562 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    78
# Train_cost  = 7.1642 | Test_cost  = 6.4897 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    79
# Train_cost  = 7.1137 | Test_cost  = 6.4278 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    80
# Train_cost  = 7.0671 | Test_cost  = 6.3701 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    81
# Train_cost  = 7.0238 | Test_cost  = 6.3160 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    82
# Train_cost  = 6.9835 | Test_cost  = 6.2650 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    83
# Train_cost  = 6.9457 | Test_cost  = 6.2169 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    84
# Train_cost  = 6.9102 | Test_cost  = 6.1714 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    85
# Train_cost  = 6.8766 | Test_cost  = 6.1283 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    86
# Train_cost  = 6.8449 | Test_cost  = 6.0874 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    87
# Train_cost  = 6.8147 | Test_cost  = 6.0487 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    88
# Train_cost  = 6.7862 | Test_cost  = 6.0119 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    89
# Train_cost  = 6.7592 | Test_cost  = 5.9770 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    90
# Train_cost  = 6.7335 | Test_cost  = 5.9437 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    91
# Train_cost  = 6.7090 | Test_cost  = 5.9119 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    92
# Train_cost  = 6.6855 | Test_cost  = 5.8814 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    93
# Train_cost  = 6.6630 | Test_cost  = 5.8521 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    94
# Train_cost  = 6.6416 | Test_cost  = 5.8243 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    95
# Train_cost  = 6.6211 | Test_cost  = 5.7979 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    96
# Train_cost  = 6.6013 | Test_cost  = 5.7728 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    97
# Train_cost  = 6.5824 | Test_cost  = 5.7487 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    98
# Train_cost  = 6.5642 | Test_cost  = 5.7254 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    99
# Train_cost  = 6.5467 | Test_cost  = 5.7030 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   100
# Train_cost  = 6.5299 | Test_cost  = 5.6813 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   101
# Train_cost  = 6.5137 | Test_cost  = 5.6605 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   102
# Train_cost  = 6.4980 | Test_cost  = 5.6405 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   103
# Train_cost  = 6.4829 | Test_cost  = 5.6213 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   104
# Train_cost  = 6.4683 | Test_cost  = 5.6027 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   105
# Train_cost  = 6.4542 | Test_cost  = 5.5848 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   106
# Train_cost  = 6.4406 | Test_cost  = 5.5674 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   107
# Train_cost  = 6.4275 | Test_cost  = 5.5505 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   108
# Train_cost  = 6.4148 | Test_cost  = 5.5340 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   109
# Train_cost  = 6.4026 | Test_cost  = 5.5179 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   110
# Train_cost  = 6.3908 | Test_cost  = 5.5022 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   111
# Train_cost  = 6.3794 | Test_cost  = 5.4869 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   112
# Train_cost  = 6.3684 | Test_cost  = 5.4720 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   113
# Train_cost  = 6.3578 | Test_cost  = 5.4575 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   114
# Train_cost  = 6.3476 | Test_cost  = 5.4435 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   115
# Train_cost  = 6.3377 | Test_cost  = 5.4299 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   116
# Train_cost  = 6.3282 | Test_cost  = 5.4167 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   117
# Train_cost  = 6.3189 | Test_cost  = 5.4039 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   118
# Train_cost  = 6.3100 | Test_cost  = 5.3915 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   119
# Train_cost  = 6.3013 | Test_cost  = 5.3796 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   120
# Train_cost  = 6.2928 | Test_cost  = 5.3681 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   121
# Train_cost  = 6.2846 | Test_cost  = 5.3569 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   122
# Train_cost  = 6.2766 | Test_cost  = 5.3462 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   123
# Train_cost  = 6.2687 | Test_cost  = 5.3358 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   124
# Train_cost  = 6.2611 | Test_cost  = 5.3258 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   125
# Train_cost  = 6.2536 | Test_cost  = 5.3162 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   126
# Train_cost  = 6.2463 | Test_cost  = 5.3068 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   127
# Train_cost  = 6.2391 | Test_cost  = 5.2978 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   128
# Train_cost  = 6.2321 | Test_cost  = 5.2891 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   129
# Train_cost  = 6.2252 | Test_cost  = 5.2806 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   130
# Train_cost  = 6.2184 | Test_cost  = 5.2725 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   131
# Train_cost  = 6.2118 | Test_cost  = 5.2646 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   132
# Train_cost  = 6.2052 | Test_cost  = 5.2570 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   133
# Train_cost  = 6.1987 | Test_cost  = 5.2496 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   134
# Train_cost  = 6.1924 | Test_cost  = 5.2424 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   135
# Train_cost  = 6.1860 | Test_cost  = 5.2354 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   136
# Train_cost  = 6.1798 | Test_cost  = 5.2287 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   137
# Train_cost  = 6.1736 | Test_cost  = 5.2222 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   138
# Train_cost  = 6.1674 | Test_cost  = 5.2158 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   139
# Train_cost  = 6.1613 | Test_cost  = 5.2096 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   140
# Train_cost  = 6.1553 | Test_cost  = 5.2035 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   141
# Train_cost  = 6.1492 | Test_cost  = 5.1976 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   142
# Train_cost  = 6.1432 | Test_cost  = 5.1918 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   143
# Train_cost  = 6.1372 | Test_cost  = 5.1862 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   144
# Train_cost  = 6.1313 | Test_cost  = 5.1808 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   145
# Train_cost  = 6.1255 | Test_cost  = 5.1756 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   146
# Train_cost  = 6.1196 | Test_cost  = 5.1705 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   147
# Train_cost  = 6.1139 | Test_cost  = 5.1657 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   148
# Train_cost  = 6.1082 | Test_cost  = 5.1610 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   149
# Train_cost  = 6.1025 | Test_cost  = 5.1565 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   150
# Train_cost  = 6.0969 | Test_cost  = 5.1522 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   151
# Train_cost  = 6.0913 | Test_cost  = 5.1480 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   152
# Train_cost  = 6.0858 | Test_cost  = 5.1439 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   153
# Train_cost  = 6.0804 | Test_cost  = 5.1400 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   154
# Train_cost  = 6.0751 | Test_cost  = 5.1362 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   155
# Train_cost  = 6.0698 | Test_cost  = 5.1324 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   156
# Train_cost  = 6.0646 | Test_cost  = 5.1288 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   157
# Train_cost  = 6.0595 | Test_cost  = 5.1254 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   158
# Train_cost  = 6.0545 | Test_cost  = 5.1220 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   159
# Train_cost  = 6.0495 | Test_cost  = 5.1188 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   160
# Train_cost  = 6.0446 | Test_cost  = 5.1156 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   161
# Train_cost  = 6.0398 | Test_cost  = 5.1127 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   162
# Train_cost  = 6.0350 | Test_cost  = 5.1099 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   163
# Train_cost  = 6.0303 | Test_cost  = 5.1072 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   164
# Train_cost  = 6.0257 | Test_cost  = 5.1047 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   165
# Train_cost  = 6.0211 | Test_cost  = 5.1024 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   166
# Train_cost  = 6.0166 | Test_cost  = 5.1002 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   167
# Train_cost  = 6.0122 | Test_cost  = 5.0982 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   168
# Train_cost  = 6.0078 | Test_cost  = 5.0964 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   169
# Train_cost  = 6.0035 | Test_cost  = 5.0948 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   170
# Train_cost  = 5.9992 | Test_cost  = 5.0934 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   171
# Train_cost  = 5.9950 | Test_cost  = 5.0922 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   172
# Train_cost  = 5.9909 | Test_cost  = 5.0912 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   173
# Train_cost  = 5.9867 | Test_cost  = 5.0903 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   174
# Train_cost  = 5.9826 | Test_cost  = 5.0897 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   175
# Train_cost  = 5.9786 | Test_cost  = 5.0893 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   176
# Train_cost  = 5.9746 | Test_cost  = 5.0890 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   177
# Train_cost  = 5.9706 | Test_cost  = 5.0889 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   178
# Train_cost  = 5.9666 | Test_cost  = 5.0890 |
# ==> EarlyStop patience =  1 | Best test_cost: 5.0889
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   179
# Train_cost  = 5.9627 | Test_cost  = 5.0893 |
# ==> EarlyStop patience =  2 | Best test_cost: 5.0889
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   180
# Train_cost  = 5.9588 | Test_cost  = 5.0896 |
# ==> EarlyStop patience =  3 | Best test_cost: 5.0889
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   181
# Train_cost  = 5.9548 | Test_cost  = 5.0901 |
# ==> EarlyStop patience =  4 | Best test_cost: 5.0889
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   182
# Train_cost  = 5.9510 | Test_cost  = 5.0908 |
# ==> EarlyStop patience =  5 | Best test_cost: 5.0889
# ==> Execute Early Stopping at epoch: 182 | Best test_cost: 5.0889
# ==> Best model is saved at model/gru

# %% [markdown]
# ## Sanity Check

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %%
from utils import data4pred, pred4pred

# %%
train_forecast_set = TimeSeriesDataset(ts_train, "Temp", 1)
trainforecastloader = DataLoader(train_forecast_set)
test_forecast_set = TimeSeriesDataset(ts_test, "Temp", 1)
testforecastloader = DataLoader(test_forecast_set)
# Out:
# (N, S, F): (2919, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (729, 1, 1)
# Note: last 0 data excluded

# %%
plt.figure(figsize=(15, 10))

plt.subplot(211)
data4pred(model, train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(212)
data4pred(model, test_forecast_set, testforecastloader, device)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#Pred 4 pred
plt.figure(figsize=(15, 5))
pred4pred(model, test_forecast_set, testforecastloader, device)
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')
